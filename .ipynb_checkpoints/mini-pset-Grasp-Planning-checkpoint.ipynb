# %%
from graphics import disp
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-65-7fa1e3ee6474> in <module>()
# ----> 1 from graphics import disp
#
# ImportError: cannot import name disp

# %%
# %load graphics.py
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation, rc

from IPython.display import HTML

class Grid(object):
    def __init__(self, initial):
        self.state = initial
        self.fig, self.ax = plt.subplots()
        self.line, = ax.plot([], [], lw=2)
    
    # initialization function: plot the background of each frame
    def init(self):
        self.line.set_data([], [])
        return (self.line,)
    
    def step(self):
        # TODO: Game of Life implementation goes here
        # Either assign a new value to self.state, or modify it
        
    def plot_step(self):
        self.step()
        # TODO: Plot here
        x = np.linspace(0, 2, 1000)
        y = np.sin(2 * np.pi * (x - 0.01 * i))
        self.line.set_data(x, y)
        return (self.line,)

initial = [(0,0), (0,1), (0,2)]
grid = Grid(initial)
anim = animation.FuncAnimation(grid.fig, grid.plot_step, init_func=grid.init, frames=100, interval=20, blit=True)

HTML(anim.to_html5_video())

# %%
initial = [(0,0), (0,1), (0,2)]
grid = Grid(initial)
anim = animation.FuncAnimation(grid.fig, grid.plot_step, init_func=grid.init, frames=100, interval=20, blit=True)
# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=100, interval=20, blit=True)

HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-8e32953dd6e8> in <module>()
#       1 initial = [(0,0), (0,1), (0,2)]
# ----> 2 grid = Grid(initial)
#       3 anim = animation.FuncAnimation(grid.fig, grid.plot_step, init_func=grid.init, frames=100, interval=20, blit=True)
#       4 # call the animator. blit=True means only re-draw the parts that have changed.
#       5 anim = animation.FuncAnimation(fig, animate, init_func=init, frames=100, interval=20, blit=True)
#
# NameError: name 'Grid' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation, rc

from IPython.display import HTML

# %%
class Grid(object):
    def __init__(self, initial):
        self.state = initial
        self.fig, self.ax = plt.subplots()
        self.line, = self.ax.plot([], [], lw=2)
    
    # initialization function: plot the background of each frame
    def init(self):
        self.line.set_data([], [])
        self.ax.set_xlim(( 0, 2))
        self.ax.set_ylim((-2, 2))

        return (self.line,)
    
    def step(self):
        # TODO: Game of Life implementation goes here
        # Either assign a new value to self.state, or modify it
        return None
    
    def plot_step(self, i):
        self.step()
        # TODO: Plot here
        x = np.linspace(0, 2, 1000)
        y = np.sin(2 * np.pi * (x - 0.01 * i))
        print "i was", i
        self.line.set_data(x, y)
        return (self.line,)

# %%
initial = [(0,0), (0,1), (0,2)]
grid = Grid(initial)
anim = animation.FuncAnimation(grid.fig, grid.plot_step, init_func=grid.init, frames=100, interval=20, blit=True)

# %%
HTML(anim.to_html5_video())
# Out:
# i was 0
# i was 1
# i was 2
# i was 3
# i was 4
# i was 5
# i was 6
# i was 7
# i was 8
# i was 9
# i was 10
# i was 11
# i was 12
# i was 13
# i was 14
# i was 15
# i was 16
# i was 17
# i was 18
# i was 19
# i was 20
# i was 21
# i was 22
# i was 23
# i was 24
# i was 25
# i was 26
# i was 27
# i was 28
# i was 29
# i was 30
# i was 31
# i was 32
# i was 33
# i was 34
# i was 35
# i was 36
# i was 37
# i was 38
# i was 39
# i was 40
# i was 41
# i was 42
# i was 43
# i was 44
# i was 45
# i was 46
# i was 47
# i was 48
# i was 49
# i was 50
# i was 51
# i was 52
# i was 53
# i was 54
# i was 55
# i was 56
# i was 57
# i was 58
# i was 59
# i was 60
# i was 61
# i was 62
# i was 63
# i was 64
# i was 65
# i was 66
# i was 67
# i was 68
# i was 69
# i was 70
# i was 71
# i was 72
# i was 73
# i was 74
# i was 75
# i was 76
# i was 77
# i was 78
# i was 79
# i was 80
# i was 81
# i was 82
# i was 83
# i was 84
# i was 85
# i was 86
# i was 87
# i was 88
# i was 89
# i was 90
# ...

# %%
fig, ax = plt.subplots()

ax.set_xlim(( 0, 2))
ax.set_ylim((-2, 2))

line, = ax.plot([], [], lw=2)

# %%
def init():
    line.set_data([], [])
    return (line,)

# %%
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return (line,)

# %%
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

# %%
HTML(anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
